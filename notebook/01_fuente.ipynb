# %%
# ============================================================
# 01 - FUENTES
# Adquisición de datos y carga inicial para el proyecto
# Predicción: Tipo de piel recomendado según ingredientes
# ============================================================

import pandas as pd
import os

# ============================================================
# 1. Crear carpetas necesarias (si no existen)
# ============================================================

carpeta_raiz = ".."
carpeta_raw = carpeta_raiz + "/data/raw"

os.makedirs(carpeta_raw, exist_ok=True)

print("Carpetas listas.")


# ============================================================
# 2. Cargar el dataset original
# ============================================================

# IMPORTANTE: Cambia esta ruta según dónde dejaste el archivo
ruta_archivo = "../data/raw/cosmetics.csv"

datos_originales = pd.read_csv(ruta_archivo)

print("Dataset cargado correctamente.")
datos_originales.head()


# ============================================================
# 3. Mostrar información básica del dataset
# ============================================================

print("\nDimensiones del dataset:")
print(datos_originales.shape)

print("\nColumnas disponibles:")
print(datos_originales.columns.tolist())

print("\nDescripción general del dataset:")
print(datos_originales.info())


# ============================================================
# 4. Guardar copia en data/raw (sin procesar)
# ============================================================

ruta_guardado = carpeta_raw + "/cosmetics.csv"
datos_originales.to_csv(ruta_guardado, index=False)

print("\nArchivo guardado en:", ruta_guardado)


# ============================================================
# 5. Explicación para continuar en el Notebook 02
# ============================================================

print("\nEl Notebook 01 ha finalizado correctamente.")
print("En el Notebook 02 realizaremos limpieza, imputación, "
      "normalización de ingredientes y creación de nuevas variables.")
# Out:
# Carpetas listas.
# Dataset cargado correctamente.
#
# Dimensiones del dataset:
# (1472, 11)
#
# Columnas disponibles:
# ['Label', 'Brand', 'Name', 'Price', 'Rank', 'Ingredients', 'Combination', 'Dry', 'Normal', 'Oily', 'Sensitive']
#
# Descripción general del dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1472 entries, 0 to 1471
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Label        1472 non-null   object
#  1   Brand        1472 non-null   object
#  2   Name         1472 non-null   object
#  3   Price        1472 non-null   int64
#  4   Rank         1472 non-null   float64
#  5   Ingredients  1472 non-null   object
#  6   Combination  1472 non-null   int64
#  7   Dry          1472 non-null   int64
#  8   Normal       1472 non-null   int64
#  9   Oily         1472 non-null   int64
#  10  Sensitive    1472 non-null   int64
# dtypes: float64(1), int64(6), object(4)
# ...
